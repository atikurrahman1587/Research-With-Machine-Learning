# %% [markdown]
# <a href="https://colab.research.google.com/github/atikurrahman1587/Research-With-Machine-Learning/blob/main/First_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("This is Md Atikur Rahman")
# Out:
# This is Md Atikur Rahman
